# %%
def Mod(a, b):
    return a%b

def mod_binary(g, k, n, p):
    y=1
    k = str(bin(k))[2:]
    for i in k:
        if i=='1':
            y = Mod(Mod(y**2, p)*g, p)
            # print(y)
        else:
            y = Mod(y**2, p)
            # print(y)
    return y

def ModBinaryExp(k):
    k = str(bin(k))[2:]
    mult_count = k.count('1')
    square_count = len(k)

    return mult_count, square_count

def inv(a, n):
    # return a^-1 mod n
    return mod_binary(a, n-2, len(str(bin(n-2))[2:]) , n)

p1 = 
g1 = 2
g2 = 74477125891023456789
g3 = 229553136239076508735759914822744771258939076508731023456789
g4 = 74477125892295531362390765087357599148227447712589390765087310234567891023456789


print("g1^-1 mod p1 =", inv(g1, p1))
print("g2^-1 mod p1 =", inv(g2, p1))
print("g3^-1 mod p1 =", inv(g3, p1))
print("g4^-1 mod p1 =", inv(g4, p1))

res = ModBinaryExp(p1-2)
print("g1^-1 mod p1 の乗算回数 =", res[0])
print("g2^-1 mod p1 の乗算回数 =", res[0])
print("g3^-1 mod p1 の乗算回数 =", res[0])
print("g4^-1 mod p1 の乗算回数 =", res[0])
print("g1^-1 mod p1 の2乗算回算 =", res[1])
print("g2^-1 mod p1 の2乗算回算 =", res[1])
print("g3^-1 mod p1 の2乗算回算 =", res[1])
print("g4^-1 mod p1 の2乗算回算 =", res[1])

print("loop_count g1 =", len(str(bin(p1-2))[2:]))
print("loop_count g2 =", len(str(bin(p1-2))[2:]))
print("loop_count g3 =", len(str(bin(p1-2))[2:]))
print("loop_count g4 =", len(str(bin(p1-2))[2:]))
# Out:
# g1^-1 mod p1 = 
# g2^-1 mod p1 = 
# g3^-1 mod p1 = 
# ...
