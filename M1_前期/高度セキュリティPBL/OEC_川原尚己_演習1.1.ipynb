# %%
def ex_euclid(a, b):
    A = [a, b]
    X = [1, 0]
    Y = [0, 1]
    i=1
    while A[-1]!=0:
        q = A[i-1]//A[i]
        a_next = A[i-1]-A[i]*q
        x_next = X[i-1]-q*X[i]
        y_next = Y[i-1]-q*Y[i]
        A.append(a_next)
        X.append(x_next)
        Y.append(y_next)
        i+=1
    
    ans = []
    ans.append((X[i-1], Y[i-1]))
    d = A[i-1]
    x = X[i-1]
    y = Y[i-1]
    return x, y, d
    # for j in range(100):
    #     x -= b//d
    #     y += a//d
    #     ans.append((x, y))
    
    # return ans

def main():
    p1 = 
    g1 = 2
    g2 = 74477125891023456789
    g3 = 229553136239076508735759914822744771258939076508731023456789
    g4 = 74477125892295531362390765087357599148227447712589390765087310234567891023456789
    
    #(1)
    _, y, _ = ex_euclid(p1, g1)
    y = y % p1
    print("inv g1 =", y)

    #(2)
    _, y, _ = ex_euclid(p1, g2)
    y = y % p1
    print("inv g2 =", y)

    #(3)
    _, y, _ = ex_euclid(p1, g3)
    y = y % p1
    print("inv g3 =", y)

    #(4)
    _, y, _ = ex_euclid(p1, g4)
    y = y % p1
    print("inv g4 =", y)

if __name__=="__main__":
    main()
# Out:
# inv g1 = 
# inv g2 = 
# inv g3 = 
# inv g4 = 
